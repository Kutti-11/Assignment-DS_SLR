# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/Assignments
# Out:
# /content/drive/MyDrive/Assignments

# %%
ls
# Out:
# assign1/  assign2/  assign3/  delivery_time.csv  Salary_Data.csv

# %%
import pandas as pd

# %%
data = pd.read_csv('delivery_time.csv')
data
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
#Renaming all columns
df = data.rename({'Delivery Time':'Delivery_Time', 'Sorting Time':'Sorting_Time'}, axis = 1)

df
# Out:
#     Delivery_Time  Sorting_Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery_Time  21 non-null     float64
#  1   Sorting_Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
df.shape
# Out:
# (21, 2)

# %%
df.head()
# Out:
#    Delivery_Time  Sorting_Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
df.tail()
# Out:
#     Delivery_Time  Sorting_Time
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
df.dtypes
# Out:
# Delivery_Time    float64
# Sorting_Time       int64
# dtype: object

# %%
#check for missing values
df.isnull().sum()
# Out:
# Delivery_Time    0
# Sorting_Time     0
# dtype: int64

# %%
#to genrate heat map
import seaborn as sns
cols = df.columns
colors = ['#000099', '#ffff00']   #define colors, yellow for missing, blue for non missing
sns.heatmap(df[cols].isnull(),
               cmap= sns.color_palette(colors))
# Out:
# <Axes: >

# %%
#to check for duplicate rows
df[df.duplicated()].shape
# Out:
# (0, 2)

# %%
df.describe()
# Out:
#        Delivery_Time  Sorting_Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %%
#Outlier Detection
import matplotlib.pyplot as plt
plt.boxplot(df['Delivery_Time'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fd35a610c70>,
#   <matplotlib.lines.Line2D at 0x7fd35a610f10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fd35a6111b0>,
#   <matplotlib.lines.Line2D at 0x7fd35a611450>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fd35a6109d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd35a6116f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd35a611990>],
#  'means': []}

# %%
import seaborn as sns

sns.distplot(df.Delivery_Time)
# Out:
# <ipython-input-17-4a83c4e37cdb>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Delivery_Time)
# <Axes: xlabel='Delivery_Time', ylabel='Density'>

# %%
plt.boxplot(df['Sorting_Time'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fd35832d870>,
#   <matplotlib.lines.Line2D at 0x7fd35832db10>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fd35832ddb0>,
#   <matplotlib.lines.Line2D at 0x7fd35832e050>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fd35832d5d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd35832e2f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd35832e590>],
#  'means': []}

# %%
sns.distplot(df.Sorting_Time)
# Out:
# <ipython-input-19-0c142cfee392>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Sorting_Time)
# <Axes: xlabel='Sorting_Time', ylabel='Density'>

# %% [markdown]
# # - Performing Transformation on each column

# %%
import numpy as np

fig, ax=plt.subplots(2, figsize=(3,4), sharex= False, sharey = False)
sns.boxplot(np.log(df.Sorting_Time), ax=ax[0])
sns.boxplot(np.log(df.Delivery_Time), ax=ax[1])
plt.suptitle("Log Transformation on Continuous Variables", fontsize= 17, y = 1.06)
plt.tight_layout(pad=2.0)

# %%
fig, ax=plt.subplots(2, figsize=(6,4), sharex= False, sharey = False)
sns.boxplot(np.sqrt(df.Sorting_Time), ax=ax[0])
sns.boxplot(np.sqrt(df.Delivery_Time), ax=ax[1])
plt.suptitle("Sqrt Transformation on Continuous Variables", fontsize= 17, y = 1.06)
plt.tight_layout(pad=2.0)

# %%
fig, ax=plt.subplots(2, figsize=(6,4), sharex= False, sharey = False)
sns.boxplot(np.cbrt(df.Sorting_Time), ax=ax[0])
sns.boxplot(np.cbrt(df.Delivery_Time), ax=ax[1])
plt.suptitle("Cbrt Transformation on Continuous Variables", fontsize= 17, y = 1.06)
plt.tight_layout(pad=2.0)

# %% [markdown]
# # Correlation

# %%
#Correlation coef
df.corr()
# Out:
#                Delivery_Time  Sorting_Time
# Delivery_Time       1.000000      0.825997
# Sorting_Time        0.825997      1.000000

# %%
sns.pairplot(df)

# %% [markdown]
# # **Fitting a Regression Equation**

# %%
import statsmodels.formula.api as smf

model = smf.ols("Delivery_Time~Sorting_Time", data=df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Delivery_Time   R-squared:                       0.682
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     40.80
# Date:                Wed, 14 Jun 2023   Prob (F-statistic):           3.98e-06
# Time:                        08:21:48   Log-Likelihood:                -51.357
# No. Observations:                  21   AIC:                             106.7
# Df Residuals:                      19   BIC:                             108.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept        6.5827      1.722      3.823      0.001       2.979      10.186
# Sorting_Time     1.6490      0.258      6.387      0.000       1.109       2.189
# ==============================================================================
# Omnibus:                        3.649   Durbin-Watson:                   1.248
# Prob(Omnibus):                  0.161   Jarque-Bera (JB):                2.086
# Skew:                           0.750   Prob(JB):                        0.352
# Kurtosis:                       3.367   Cond. No.                         18.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
model.params
# Out:
# Intercept       6.582734
# Sorting_Time    1.649020
# dtype: float64

# %%
print(model.tvalues, '\n',model.pvalues)
# Out:
# Intercept       3.823349
# Sorting_Time    6.387447
# dtype: float64
#  Intercept       0.001147
# Sorting_Time    0.000004
# dtype: float64

# %%
model.rsquared
# Out:
# 0.6822714748417231

# %%
sns.regplot(x = "Sorting_Time", y = "Delivery_Time", data = df)
# Out:
# <Axes: xlabel='Sorting_Time', ylabel='Delivery_Time'>

# %% [markdown]
# *Residual Analysis*
#
# *Test for Noramlity of Residual through QQ plot*

# %%
import statsmodels.api as sm

#q line is the 45 degrees line
qqplot = sm.qqplot(model.resid, line= 'q')
plt.title('Normal Q-Q Plot of Residual')
plt.show()

# %%
import numpy as np
list(np.where(model.resid>6))
# Out:
# [array([20])]

# %% [markdown]
# *Residual plot for Homoscedasticity*

# %%
def get_standardize_values( vals):
  return (vals - vals.mean())/vals.std() # get standardized values of fitted values and residual

# %%
plt.scatter(get_standardize_values(model.fittedvalues), get_standardize_values(model.resid))
plt.ylabel('Standardize Residual values')
plt.xlabel('Standardize Fitted values')
plt.title('Residaul Plot')
plt.show()

# %% [markdown]
# *Residual vs Regressors*

# %%
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Sorting_Time", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# *Model Deletion by Cook's Distance and Leverage value*

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20,8))
plt.stem(np.arange(len(df)), np.round(c,3))
plt.xlabel('Row Index')
plt.ylabel('Cooks Distance')
plt.show()

# %%
#index and values of influencers where c is more than .5
(np.argmax(c), np.max(c))
# Out:
# (4, 0.462053041265031)

# %%
from statsmodels.graphics.regressionplots import influence_plot

influence_plot(model)
plt.show()

# %%
k = df.shape[1]
n = df.shape[0]
leverage_cutoff = 3*(k+1)/n

# %%
leverage_cutoff
# Out:
# 0.42857142857142855

# %% [markdown]
# From the above plots, as C<1 & leverage_cutoff value is higher than any datapoint, hence we will not delete any datapoint.

# %% [markdown]
# *Prediction*

# %%
#Predict Delivery Time for Sorting Time = 5, 10
newdata = pd.Series([5,10])

data_pred = pd.DataFrame(newdata, columns = ['Sorting_Time'])

data_pred
# Out:
#    Sorting_Time
# 0             5
# 1            10

# %%
model.predict(data_pred)
# Out:
# 0    14.827833
# 1    23.072933
# dtype: float64
